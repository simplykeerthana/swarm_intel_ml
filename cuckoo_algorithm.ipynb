# %% [markdown]
# # Feature selection using Cuckoo Search

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from niapy.problems import Problem
from niapy.task import Task

from niapy.algorithms.basic import CuckooSearch
import pandas as np
import pandas as pd
from sklearn import svm
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
class GaussianNBFeatureSelection(Problem):
    def __init__(self, X_train, y_train, alpha=0.99):
        super().__init__(dimension=X_train.shape[1], lower=0, upper=1)
        self.X_train = X_train
        self.y_train = y_train
        self.alpha = alpha

    def _evaluate(self, x):
        selected = x > 0.5
        num_selected = selected.sum()
        if num_selected == 0:
            return 1.0
        accuracy = cross_val_score(GaussianNB(), self.X_train[:, selected], self.y_train, cv=2, n_jobs=-1).mean()
        score = 1 - accuracy
        num_features = self.X_train.shape[1]
        return self.alpha * score + (1 - self.alpha) * (num_selected / num_features)

# %%
class LogisticRegressionFeatureSelection(Problem):
    def __init__(self, X_train, y_train, alpha=0.99):
        super().__init__(dimension=X_train.shape[1], lower=0, upper=1)
        self.X_train = X_train
        self.y_train = y_train
        self.alpha = alpha

    def _evaluate(self, x):
        selected = x > 0.5
        num_selected = selected.sum()
        if num_selected == 0:
            return 1.0
        accuracy = cross_val_score(LogisticRegression(), self.X_train[:, selected], self.y_train, cv=2, n_jobs=-1).mean()
        score = 1 - accuracy
        num_features = self.X_train.shape[1]
        return self.alpha * score + (1 - self.alpha) * (num_selected / num_features)

# %%
class DecisionTreeClassifierFeatureSelection(Problem):
    def __init__(self, X_train, y_train, alpha=0.99):
        super().__init__(dimension=X_train.shape[1], lower=0, upper=1)
        self.X_train = X_train
        self.y_train = y_train
        self.alpha = alpha

    def _evaluate(self, x):
        selected = x > 0.5
        num_selected = selected.sum()
        if num_selected == 0:
            return 1.0
        accuracy = cross_val_score(DecisionTreeClassifier(), self.X_train[:, selected], self.y_train, cv=2, n_jobs=-1).mean()
        score = 1 - accuracy
        num_features = self.X_train.shape[1]
        return self.alpha * score + (1 - self.alpha) * (num_selected / num_features)

# %%
class KNeighborsClassifierFeatureSelection(Problem):
    def __init__(self, X_train, y_train, alpha=0.99):
        super().__init__(dimension=X_train.shape[1], lower=0, upper=1)
        self.X_train = X_train
        self.y_train = y_train
        self.alpha = alpha

    def _evaluate(self, x):
        selected = x > 0.5
        num_selected = selected.sum()
        if num_selected == 0:
            return 1.0
        accuracy = cross_val_score(KNeighborsClassifier(), self.X_train[:, selected], self.y_train, cv=2, n_jobs=-1).mean()
        score = 1 - accuracy
        num_features = self.X_train.shape[1]
        return self.alpha * score + (1 - self.alpha) * (num_selected / num_features)

# %%
class SVMFeatureSelection(Problem):
    def __init__(self, X_train, y_train, alpha=0.99):
        super().__init__(dimension=X_train.shape[1], lower=0, upper=1)
        self.X_train = X_train
        self.y_train = y_train
        self.alpha = alpha

    def _evaluate(self, x):
        selected = x > 0.5
        num_selected = selected.sum()
        if num_selected == 0:
            return 1.0
        accuracy = cross_val_score(SVC(), self.X_train[:, selected], self.y_train, cv=2, n_jobs=-1).mean()
        score = 1 - accuracy
        num_features = self.X_train.shape[1]
        return self.alpha * score + (1 - self.alpha) * (num_selected / num_features)

# %%
dataset = load_breast_cancer()
X = dataset.data
y = dataset.target
feature_names = dataset.feature_names

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=1234)

problem_nb = GaussianNBFeatureSelection(X_train, y_train)
problem_lr = LogisticRegressionFeatureSelection(X_train, y_train)
problem_dt = DecisionTreeClassifierFeatureSelection(X_train, y_train)
problem_knn = KNeighborsClassifierFeatureSelection(X_train, y_train)
problem_svc = SVMFeatureSelection(X_train, y_train)
#task = Task(problem, max_iters=200)

# %%
cuckoodict = {}

# %% [markdown]
# # Cuckoo Search (1/2: Change to population size)

# %%
# Set saved variable for checked parameters
bestScore = 0.0
bestCriterion = None
pop_num = 0
pop_features = None

for x in range(10,80,15):
    # GaussianNB
    task = Task(problem_nb, max_iters=200)
        
    print("-"*50)
    print("Cuckoo search: Population size = "+ str(x))
    algorithm = CuckooSearch(population_size=x, pa=0.25)
    best_features, best_fitness = algorithm.run(task=task)
    selected_features = best_features > 0.5
    print('Number of selected features:', selected_features.sum())
    print('Selected features:', ', '.join(feature_names[selected_features].tolist()))
    features1 = feature_names[selected_features].tolist()
    
    model_selected = GaussianNB()
    model_all = GaussianNB()
    model_name = "GaussianNB"

    model_selected.fit(X_train[:, selected_features], y_train)
    subset_acc = model_selected.score(X_test[:, selected_features], y_test)
    print(model_name + 'Subset accuracy:', subset_acc)       
    if subset_acc > bestScore:
        bestScore = subset_acc
        bestCriterion = x
        pop_num = selected_features.sum()
        pop_features = feature_names[selected_features].tolist()
    model_all.fit(X_train, y_train)
    print(model_name + 'All Features Accuracy:', model_all.score(X_test, y_test))
    
    # DecisionTreeClassifier
    task = Task(problem_dt, max_iters=200)
        
    print("-"*50)
    print("Cuckoo search: Population size = "+ str(x))
    algorithm = CuckooSearch(population_size=x, pa=0.25)
    best_features, best_fitness = algorithm.run(task=task)
    selected_features = best_features > 0.5
    print('Number of selected features:', selected_features.sum())
    print('Selected features:', ', '.join(feature_names[selected_features].tolist()))
    features1 = feature_names[selected_features].tolist()
    
    model_selected = DecisionTreeClassifier()
    model_all = DecisionTreeClassifier()
    model_name = "DecisionTreeClassifier"

    model_selected.fit(X_train[:, selected_features], y_train)
    subset_acc = model_selected.score(X_test[:, selected_features], y_test)
    print(model_name + 'Subset accuracy:', subset_acc)       
    if subset_acc > bestScore:
        bestScore = subset_acc
        bestCriterion = x
        pop_num = selected_features.sum()
        pop_features = feature_names[selected_features].tolist()
    model_all.fit(X_train, y_train)
    print(model_name + 'All Features Accuracy:', model_all.score(X_test, y_test))
    
    # KNeighborsClassifier
    task = Task(problem_knn, max_iters=200)
        
    print("-"*50)
    print("Cuckoo search: Population size = "+ str(x))
    algorithm = CuckooSearch(population_size=x, pa=0.25)
    best_features, best_fitness = algorithm.run(task=task)
    selected_features = best_features > 0.5
    print('Number of selected features:', selected_features.sum())
    print('Selected features:', ', '.join(feature_names[selected_features].tolist()))
    features1 = feature_names[selected_features].tolist()
    
    model_selected = KNeighborsClassifier()
    model_all = KNeighborsClassifier()
    model_name = "KNeighborsClassifier"

    model_selected.fit(X_train[:, selected_features], y_train)
    subset_acc = model_selected.score(X_test[:, selected_features], y_test)
    print(model_name + 'Subset accuracy:', subset_acc)       
    if subset_acc > bestScore:
        bestScore = subset_acc
        bestCriterion = x
        pop_num = selected_features.sum()
        pop_features = feature_names[selected_features].tolist()
    model_all.fit(X_train, y_train)
    print(model_name + 'All Features Accuracy:', model_all.score(X_test, y_test))
    
    # SVC    
    task = Task(problem_svc, max_iters=200)
        
    print("-"*50)
    print("Cuckoo search: Population size = "+ str(x))
    algorithm = CuckooSearch(population_size=x, pa=0.25)
    best_features, best_fitness = algorithm.run(task=task)
    selected_features = best_features > 0.5
    print('Number of selected features:', selected_features.sum())
    print('Selected features:', ', '.join(feature_names[selected_features].tolist()))
    features1 = feature_names[selected_features].tolist()
    
    model_selected = SVC()
    model_all = SVC()
    model_name = "SVC"

    model_selected.fit(X_train[:, selected_features], y_train)
    subset_acc = model_selected.score(X_test[:, selected_features], y_test)
    print(model_name + 'Subset accuracy:', subset_acc)       
    if subset_acc > bestScore:
        bestScore = subset_acc
        bestCriterion = x
        pop_num = selected_features.sum()
        pop_features = feature_names[selected_features].tolist()
    model_all.fit(X_train, y_train)
    print(model_name + 'All Features Accuracy:', model_all.score(X_test, y_test))

cuckoodict["Cuckoo-Population"] = "pop: " + str(bestCriterion) + ", accuracy: " + str(round(bestScore, 5))
# Out:
# --------------------------------------------------
# Cuckoo search: Population size = 10
# Number of selected features: 9
# Selected features: mean texture, mean concave points, texture error, smoothness error, symmetry error, worst texture, worst area, worst smoothness, worst concave points
# GaussianNBSubset accuracy: 0.956140350877193
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: Population size = 10
# Number of selected features: 12
# Selected features: mean texture, mean perimeter, mean area, mean compactness, mean fractal dimension, perimeter error, smoothness error, compactness error, concavity error, concave points error, worst area, worst smoothness
# DecisionTreeClassifierSubset accuracy: 0.9473684210526315
# DecisionTreeClassifierAll Features Accuracy: 0.9473684210526315
# --------------------------------------------------
# Cuckoo search: Population size = 10
# Number of selected features: 7
# Selected features: mean radius, mean texture, mean symmetry, perimeter error, worst radius, worst perimeter, worst smoothness
# KNeighborsClassifierSubset accuracy: 0.956140350877193
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: Population size = 10
# Number of selected features: 4
# Selected features: mean radius, fractal dimension error, worst texture, worst perimeter
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859
# --------------------------------------------------
# Cuckoo search: Population size = 25
# Number of selected features: 9
# Selected features: mean texture, mean smoothness, mean concave points, symmetry error, worst texture, worst perimeter, worst area, worst concave points, worst symmetry
# GaussianNBSubset accuracy: 0.956140350877193
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: Population size = 25
# Number of selected features: 11
# Selected features: mean texture, mean perimeter, mean concave points, area error, concave points error, worst radius, worst texture, worst perimeter, worst compactness, worst concave points, worst fractal dimension
# DecisionTreeClassifierSubset accuracy: 0.956140350877193
# DecisionTreeClassifierAll Features Accuracy: 0.956140350877193
# --------------------------------------------------
# Cuckoo search: Population size = 25
# Number of selected features: 9
# Selected features: mean texture, mean concave points, mean fractal dimension, concavity error, fractal dimension error, worst radius, worst perimeter, worst smoothness, worst symmetry
# KNeighborsClassifierSubset accuracy: 0.9649122807017544
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: Population size = 25
# Number of selected features: 6
# Selected features: mean texture, mean symmetry, worst radius, worst texture, worst perimeter, worst concave points
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859
# --------------------------------------------------
# Cuckoo search: Population size = 40
# Number of selected features: 7
# Selected features: mean texture, texture error, smoothness error, concave points error, worst texture, worst area, worst concave points
# GaussianNBSubset accuracy: 0.9736842105263158
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: Population size = 40
# Number of selected features: 13
# Selected features: mean radius, mean texture, mean concave points, mean symmetry, mean fractal dimension, texture error, perimeter error, area error, concavity error, worst area, worst smoothness, worst compactness, worst concave points
# DecisionTreeClassifierSubset accuracy: 0.9736842105263158
# DecisionTreeClassifierAll Features Accuracy: 0.956140350877193
# --------------------------------------------------
# Cuckoo search: Population size = 40
# Number of selected features: 4
# Selected features: mean texture, symmetry error, worst radius, worst perimeter
# KNeighborsClassifierSubset accuracy: 0.9649122807017544
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: Population size = 40
# Number of selected features: 4
# Selected features: texture error, worst radius, worst texture, worst perimeter
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859
# --------------------------------------------------
# Cuckoo search: Population size = 55
# Number of selected features: 11
# Selected features: mean texture, mean smoothness, mean concave points, mean symmetry, mean fractal dimension, symmetry error, worst radius, worst texture, worst area, worst concave points, worst symmetry
# GaussianNBSubset accuracy: 0.956140350877193
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: Population size = 55
# Number of selected features: 9
# Selected features: mean texture, mean concavity, mean concave points, compactness error, concavity error, worst radius, worst area, worst compactness, worst concave points
# DecisionTreeClassifierSubset accuracy: 0.9824561403508771
# DecisionTreeClassifierAll Features Accuracy: 0.956140350877193
# --------------------------------------------------
# Cuckoo search: Population size = 55
# Number of selected features: 3
# Selected features: mean texture, worst radius, worst perimeter
# KNeighborsClassifierSubset accuracy: 0.9649122807017544
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: Population size = 55
# Number of selected features: 4
# Selected features: mean radius, concave points error, worst texture, worst perimeter
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859
# --------------------------------------------------
# Cuckoo search: Population size = 70
# Number of selected features: 7
# Selected features: mean texture, mean fractal dimension, texture error, smoothness error, worst texture, worst area, worst concave points
# GaussianNBSubset accuracy: 0.9736842105263158
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: Population size = 70
# Number of selected features: 12
# Selected features: mean texture, mean compactness, mean concavity, mean concave points, perimeter error, area error, compactness error, concavity error, concave points error, worst area, worst concavity, worst concave points
# DecisionTreeClassifierSubset accuracy: 0.9912280701754386
# DecisionTreeClassifierAll Features Accuracy: 0.956140350877193
# --------------------------------------------------
# Cuckoo search: Population size = 70
# Number of selected features: 5
# Selected features: mean texture, mean concave points, smoothness error, worst radius, worst perimeter
# KNeighborsClassifierSubset accuracy: 0.9649122807017544
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: Population size = 70
# Number of selected features: 4
# Selected features: mean concave points, worst radius, worst texture, worst perimeter
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859

# %%
cuckoodict
# Out:
# {'Cuckoo-Population': 'pop: 70, accuracy: 0.99123'}

# %% [markdown]
# # Cuckoo Search (2/2: Change to the probability of nest being abandoned (pa))

# %%
# Set saved variable for checked parameters
bestScore = 0.0
bestCriterion = None
pa_num = 0
pa_features = None

for x in range(25, 100, 15):
    # GaussianNB
    task = Task(problem_nb, max_iters=200)
    
    print("-"*50)
    print("Cuckoo search: pa = "+ str(x/100))
    algorithm = CuckooSearch(population_size=25, pa=x/100)
    best_features, best_fitness = algorithm.run(task=task)
    selected_features = best_features > 0.5
    print('Number of selected features:', selected_features.sum())
    print('Selected features:', ', '.join(feature_names[selected_features].tolist()))
    features1 = feature_names[selected_features].tolist()
        
    model_selected = GaussianNB()
    model_all = GaussianNB()
    model_name = "GaussianNB"

    model_selected.fit(X_train[:, selected_features], y_train)
    subset_acc = model_selected.score(X_test[:, selected_features], y_test)
    print(model_name + 'Subset accuracy:', subset_acc)
    if subset_acc > bestScore:
        bestScore = subset_acc
        bestCriterion = x
        pa_num = selected_features.sum()
        pa_features = feature_names[selected_features].tolist()
    model_all.fit(X_train, y_train)
    print(model_name + 'All Features Accuracy:', model_all.score(X_test, y_test))
    
    # DecisionTreeClassifier
    task = Task(problem_dt, max_iters=200)
    
    print("-"*50)
    print("Cuckoo search: pa = "+ str(x/100))
    algorithm = CuckooSearch(population_size=25, pa=x/100)
    best_features, best_fitness = algorithm.run(task=task)
    selected_features = best_features > 0.5
    print('Number of selected features:', selected_features.sum())
    print('Selected features:', ', '.join(feature_names[selected_features].tolist()))
    features1 = feature_names[selected_features].tolist()
        
    model_selected = DecisionTreeClassifier()
    model_all = DecisionTreeClassifier()
    model_name = "DecisionTreeClassifier"

    model_selected.fit(X_train[:, selected_features], y_train)
    subset_acc = model_selected.score(X_test[:, selected_features], y_test)
    print(model_name + 'Subset accuracy:', subset_acc)
    if subset_acc > bestScore:
        bestScore = subset_acc
        bestCriterion = x
        pa_num = selected_features.sum()
        pa_features = feature_names[selected_features].tolist()
    model_all.fit(X_train, y_train)
    print(model_name + 'All Features Accuracy:', model_all.score(X_test, y_test))
    
    # KNeighborsClassifier
    task = Task(problem_knn, max_iters=200)
    
    print("-"*50)
    print("Cuckoo search: pa = "+ str(x/100))
    algorithm = CuckooSearch(population_size=25, pa=x/100)
    best_features, best_fitness = algorithm.run(task=task)
    selected_features = best_features > 0.5
    print('Number of selected features:', selected_features.sum())
    print('Selected features:', ', '.join(feature_names[selected_features].tolist()))
    features1 = feature_names[selected_features].tolist()
        
    model_selected = KNeighborsClassifier()
    model_all = KNeighborsClassifier()
    model_name = "KNeighborsClassifier"

    model_selected.fit(X_train[:, selected_features], y_train)
    subset_acc = model_selected.score(X_test[:, selected_features], y_test)
    print(model_name + 'Subset accuracy:', subset_acc)
    if subset_acc > bestScore:
        bestScore = subset_acc
        bestCriterion = x
        pa_num = selected_features.sum()
        pa_features = feature_names[selected_features].tolist()
    model_all.fit(X_train, y_train)
    print(model_name + 'All Features Accuracy:', model_all.score(X_test, y_test))
    
    # SVC     
    task = Task(problem_svc, max_iters=200)
    
    print("-"*50)
    print("Cuckoo search: pa = "+ str(x/100))
    algorithm = CuckooSearch(population_size=25, pa=x/100)
    best_features, best_fitness = algorithm.run(task=task)
    selected_features = best_features > 0.5
    print('Number of selected features:', selected_features.sum())
    print('Selected features:', ', '.join(feature_names[selected_features].tolist()))
    features1 = feature_names[selected_features].tolist()
        
    model_selected = SVC()
    model_all = SVC()
    model_name = "SVC"

    model_selected.fit(X_train[:, selected_features], y_train)
    subset_acc = model_selected.score(X_test[:, selected_features], y_test)
    print(model_name + 'Subset accuracy:', subset_acc)
    if subset_acc > bestScore:
        bestScore = subset_acc
        bestCriterion = x
        pa_num = selected_features.sum()
        pa_features = feature_names[selected_features].tolist()
    model_all.fit(X_train, y_train)
    print(model_name + 'All Features Accuracy:', model_all.score(X_test, y_test))
    
cuckoodict["Cuckoo-Pa"] = "pa: " + str(bestCriterion) + ", accuracy: " + str(round(bestScore, 5))
# Out:
# --------------------------------------------------
# Cuckoo search: pa = 0.25
# Number of selected features: 7
# Selected features: mean texture, mean concave points, mean fractal dimension, worst texture, worst area, worst smoothness, worst concave points
# GaussianNBSubset accuracy: 0.956140350877193
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: pa = 0.25
# Number of selected features: 12
# Selected features: mean area, mean compactness, mean concave points, texture error, perimeter error, smoothness error, concave points error, fractal dimension error, worst texture, worst area, worst smoothness, worst concave points
# DecisionTreeClassifierSubset accuracy: 0.9473684210526315
# DecisionTreeClassifierAll Features Accuracy: 0.956140350877193
# --------------------------------------------------
# Cuckoo search: pa = 0.25
# Number of selected features: 7
# Selected features: mean texture, mean concave points, radius error, symmetry error, worst radius, worst perimeter, worst concave points
# KNeighborsClassifierSubset accuracy: 0.956140350877193
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: pa = 0.25
# Number of selected features: 3
# Selected features: mean concave points, worst texture, worst perimeter
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859
# --------------------------------------------------
# Cuckoo search: pa = 0.4
# Number of selected features: 9
# Selected features: mean texture, mean concave points, mean fractal dimension, texture error, smoothness error, worst texture, worst area, worst smoothness, worst concave points
# GaussianNBSubset accuracy: 0.956140350877193
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: pa = 0.4
# Number of selected features: 10
# Selected features: mean texture, mean compactness, mean concave points, mean fractal dimension, radius error, area error, worst texture, worst area, worst compactness, worst concave points
# DecisionTreeClassifierSubset accuracy: 0.9473684210526315
# DecisionTreeClassifierAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: pa = 0.4
# Number of selected features: 6
# Selected features: mean radius, mean texture, perimeter error, worst radius, worst perimeter, worst smoothness
# KNeighborsClassifierSubset accuracy: 0.956140350877193
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: pa = 0.4
# Number of selected features: 4
# Selected features: compactness error, fractal dimension error, worst texture, worst perimeter
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859
# --------------------------------------------------
# Cuckoo search: pa = 0.55
# Number of selected features: 7
# Selected features: mean texture, mean concave points, mean fractal dimension, worst texture, worst area, worst smoothness, worst concave points
# GaussianNBSubset accuracy: 0.956140350877193
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: pa = 0.55
# Number of selected features: 11
# Selected features: mean radius, mean texture, mean perimeter, mean concavity, mean concave points, mean symmetry, smoothness error, compactness error, symmetry error, worst area, worst concave points
# DecisionTreeClassifierSubset accuracy: 0.9824561403508771
# DecisionTreeClassifierAll Features Accuracy: 0.956140350877193
# --------------------------------------------------
# Cuckoo search: pa = 0.55
# Number of selected features: 5
# Selected features: mean texture, concave points error, worst radius, worst perimeter, worst fractal dimension
# KNeighborsClassifierSubset accuracy: 0.9649122807017544
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: pa = 0.55
# Number of selected features: 4
# Selected features: worst radius, worst texture, worst perimeter, worst symmetry
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859
# --------------------------------------------------
# Cuckoo search: pa = 0.7
# Number of selected features: 9
# Selected features: mean texture, radius error, texture error, smoothness error, concavity error, fractal dimension error, worst radius, worst texture, worst concave points
# GaussianNBSubset accuracy: 0.9649122807017544
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: pa = 0.7
# Number of selected features: 13
# Selected features: mean texture, mean perimeter, mean area, mean concavity, mean concave points, radius error, perimeter error, area error, concavity error, worst radius, worst area, worst smoothness, worst concave points
# DecisionTreeClassifierSubset accuracy: 0.9912280701754386
# DecisionTreeClassifierAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: pa = 0.7
# Number of selected features: 6
# Selected features: mean texture, radius error, smoothness error, fractal dimension error, worst radius, worst perimeter
# KNeighborsClassifierSubset accuracy: 0.956140350877193
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: pa = 0.7
# Number of selected features: 4
# Selected features: mean radius, worst texture, worst perimeter, worst fractal dimension
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859
# --------------------------------------------------
# Cuckoo search: pa = 0.85
# Number of selected features: 7
# Selected features: mean texture, radius error, fractal dimension error, worst texture, worst perimeter, worst smoothness, worst concave points
# GaussianNBSubset accuracy: 0.9649122807017544
# GaussianNBAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: pa = 0.85
# Number of selected features: 11
# Selected features: mean perimeter, mean area, mean smoothness, texture error, smoothness error, concave points error, worst radius, worst texture, worst smoothness, worst concavity, worst concave points
# DecisionTreeClassifierSubset accuracy: 0.9385964912280702
# DecisionTreeClassifierAll Features Accuracy: 0.9649122807017544
# --------------------------------------------------
# Cuckoo search: pa = 0.85
# Number of selected features: 5
# Selected features: mean texture, mean fractal dimension, worst radius, worst perimeter, worst concavity
# KNeighborsClassifierSubset accuracy: 0.9649122807017544
# KNeighborsClassifierAll Features Accuracy: 0.9210526315789473
# --------------------------------------------------
# Cuckoo search: pa = 0.85
# Number of selected features: 5
# Selected features: mean texture, mean symmetry, worst texture, worst perimeter, worst compactness
# SVCSubset accuracy: 0.956140350877193
# SVCAll Features Accuracy: 0.9122807017543859

# %% [markdown]
# # Data Preprocess

# %%
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['target'] = dataset.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
cuckoodict
# Out:
# {'Cuckoo-Population': 'pop: 70, accuracy: 0.99123',
#  'Cuckoo-Pa': 'pa: 70, accuracy: 0.99123'}

# %%
print("pop_num: {}, pop_features: {}\npa_num: {}, pa_features: {}\nn".format(pop_num, pop_features, pa_num, pa_features))
# Out:
# pop_num: 12, pop_features: ['mean texture', 'mean compactness', 'mean concavity', 'mean concave points', 'perimeter error', 'area error', 'compactness error', 'concavity error', 'concave points error', 'worst area', 'worst concavity', 'worst concave points']
# pa_num: 13, pa_features: ['mean texture', 'mean perimeter', 'mean area', 'mean concavity', 'mean concave points', 'radius error', 'perimeter error', 'area error', 'concavity error', 'worst radius', 'worst area', 'worst smoothness', 'worst concave points']
# n

# %%
newdf = df.drop(columns=[col for col in df if col not in pop_features])
newdf.head()
# Out:
#    mean texture  mean compactness  mean concavity  mean concave points  \
# 0         10.38           0.27760          0.3001              0.14710
# 1         17.77           0.07864          0.0869              0.07017
# 2         21.25           0.15990          0.1974              0.12790
# 3         20.38           0.28390          0.2414              0.10520
# 4         14.34           0.13280          0.1980              0.10430
#
#    perimeter error  area error  compactness error  concavity error  \
# 0            8.589      153.40            0.04904          0.05373
# 1            3.398       74.08            0.01308          0.01860
# 2            4.585       94.03            0.04006          0.03832
# 3            3.445       27.23            0.07458          0.05661
# 4            5.438       94.44            0.02461          0.05688
#
#    concave points error  worst area  worst concavity  worst concave points
# 0               0.01587      2019.0           0.7119                0.2654
# 1               0.01340      1956.0           0.2416                0.1860
# 2               0.02058      1709.0           0.4504                0.2430
# 3               0.01867       567.7           0.6869                0.2575
# 4               0.01885      1575.0           0.4000                0.1625

# %%
y =  dataset.target
X = newdf
print(X.shape, y.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 21)

#Feature Scaling, this is important as itt will allow the algorithm to quickly learn a better solution.
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# (569, 12) (569,)

# %% [markdown]
# # Naive Bayes Model

# %%
def gaussianNB():
    
    from sklearn.naive_bayes import GaussianNB
    gnb = GaussianNB()
    gnb.fit(X_train,y_train)
    y_pred_test = gnb.predict(X_test)
    from sklearn.metrics import accuracy_score
    acc = accuracy_score(y_test,y_pred_test)
    print("Naive Bayes : ", acc)
    b_class = ["benign", "malign"]
    print(classification_report(y_test, y_pred_test, target_names=b_class))
    
    return y_pred_test

# %% [markdown]
# # LR Model

# %%
def logisticRegression():
    from sklearn.linear_model import LogisticRegression
    logreg = LogisticRegression(solver = 'liblinear',multi_class='auto')
    logreg.fit(X_train,y_train)
    y_pred = logreg.predict(X_test)
    from sklearn.metrics import accuracy_score
    acc1 = accuracy_score(y_test,y_pred)
    print("Logistic Regression: ", acc1)
    b_class = ["benign", "malign"]
    print(classification_report(y_test, y_pred, target_names=b_class))
    
    return y_pred

# %% [markdown]
# # Decision Tree Model

# %%
def decisionTrees():
    from sklearn.tree import DecisionTreeClassifier
    dt = DecisionTreeClassifier()
    dt.fit(X_train,y_train)
    y_pred2 = dt.predict(X_test)
    acc2 = accuracy_score(y_test,y_pred2)
    print(acc2)
    print("Decision Trees:", acc2)
    b_class = ["benign", "malign"]
    print(classification_report(y_test, y_pred2, target_names=b_class))

    return y_pred2

# %% [markdown]
# # KNN Model

# %%
def knn():
    
    from sklearn.neighbors import KNeighborsClassifier
    clf = KNeighborsClassifier(n_neighbors=8,algorithm='ball_tree')
    clf.fit(X_train,y_train)
    y_pred3 = clf.predict(X_test)
    acc3 =   accuracy_score(y_test,y_pred3)
    print("K Nearest Neighbors: ", acc3)
    b_class = ["benign", "malign"]
    print(classification_report(y_test, y_pred3, target_names=b_class))  
    
    return y_pred3

# %% [markdown]
# # Support Vector Model

# %%
def svc():
    
    from sklearn.svm import SVC
    svc1 = SVC(C=50,kernel='rbf',gamma=1)     
    svc1.fit(X_train,y_train)
    y_pred4 = svc1.predict(X_test)
    from sklearn.metrics import accuracy_score
    acc4=    accuracy_score(y_test,y_pred4)
    print("Support Vector Classifier Accuracy", acc4)
    b_class = ["benign", "malign"]
    print(classification_report(y_test, y_pred4, target_names=b_class))  
    
    return y_pred4

# %% [markdown]
# # Model Results

# %%
models = {
        "gaussianNB": gaussianNB(),
        "decisionTrees": decisionTrees() ,
        "logisticRegression": logisticRegression(),
        "svc": svc(),
        "knn": knn()
    }

results = {}
print("\nNow testing algorithms")
for algo in models:

    print("trained model: ", algo )

print("\n")
# Out:
# Naive Bayes :  0.9298245614035088
#               precision    recall  f1-score   support
#
#       benign       0.90      0.90      0.90        39
#       malign       0.95      0.95      0.95        75
#
#     accuracy                           0.93       114
#    macro avg       0.92      0.92      0.92       114
# weighted avg       0.93      0.93      0.93       114
#
# 0.9035087719298246
# Decision Trees: 0.9035087719298246
#               precision    recall  f1-score   support
#
#       benign       0.89      0.82      0.85        39
#       malign       0.91      0.95      0.93        75
#
#     accuracy                           0.90       114
#    macro avg       0.90      0.88      0.89       114
# weighted avg       0.90      0.90      0.90       114
#
# Logistic Regression:  0.9912280701754386
#               precision    recall  f1-score   support
#
#       benign       1.00      0.97      0.99        39
#       malign       0.99      1.00      0.99        75
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Support Vector Classifier Accuracy 0.956140350877193
#               precision    recall  f1-score   support
#
#       benign       0.89      1.00      0.94        39
#       malign       1.00      0.93      0.97        75
#
#     accuracy                           0.96       114
#    macro avg       0.94      0.97      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# K Nearest Neighbors:  0.9824561403508771
#               precision    recall  f1-score   support
#
#       benign       1.00      0.95      0.97        39
#       malign       0.97      1.00      0.99        75
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.97      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
#
# Now testing algorithms
# trained model:  gaussianNB
# trained model:  decisionTrees
# trained model:  logisticRegression
# trained model:  svc
# trained model:  knn

# %%
cuckoodict
# Out:
# {'Cuckoo-Population': 'pop: 70, accuracy: 0.99123',
#  'Cuckoo-Pa': 'pa: 70, accuracy: 0.99123'}
